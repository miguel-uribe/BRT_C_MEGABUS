# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
busdata = np.loadtxt('results/sim_results__600_600_600_600_1000000_600_1000_1000_50_anim.txt')

# %%
mask = busdata[:,14]==999

# %%
sns.scatterplot(x=busdata[:,0], y=busdata[:,3], hue = busdata[:, 2], s = 2)
#plt.xlim(14600, 14650)
plt.show()

# %%
sns.histplot(busdata[:, 17])
# Out:
# <Axes: ylabel='Count'>
